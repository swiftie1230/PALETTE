# %% [markdown]
# ###### <a href="https://colab.research.google.com/github/kmeng01/rome/blob/main/notebooks/rome.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/rome
# git clone https://github.com/kmeng01/rome rome > install.log 2>&1
# pip install -r /content/rome/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1

# %%
IS_COLAB = False
ALL_DEPS = False
try:
    import google.colab, torch, os

    IS_COLAB = True
    os.chdir("/content/rome")
    if not torch.cuda.is_available():
        raise Exception("Change runtime type to include a GPU.")
except ModuleNotFoundError as _:
    pass

# %% [markdown]
# # Rank-One Model Editing (ROME)
# This notebook enables interactive experimentation with ROME and several other comparable baselines.
# The goal is to write new facts (e.g. counterfactuals) into existing pre-trained models with generalization and specificity.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

from util import nethook
from util.generate import generate_interactive, generate_fast

from experiments.py.demo import demo_model_editing, stop_execution

# %% [markdown]
# Here, you can specify a GPT model (`MODEL_NAME`).
#
# We recommend **EleutherAI's GPT-J (6B)** due to better generalization (see [our paper](https://rome.baulab.info/) for details), but GPT-2 XL (1.5B) consumes less memory.
# * `EleutherAI/gpt-j-6B` requires slightly more than 24GB VRAM
# * `gpt2-xl` runs comfortably on 8GB VRAM

# %%
MODEL_NAME = "Qwen/Qwen2.5-1.5B-Instruct"

# %%
model, tok = (
    AutoModelForCausalLM.from_pretrained(MODEL_NAME, low_cpu_mem_usage=True, torch_dtype=torch.float32,).to('cuda'),
    AutoTokenizer.from_pretrained(MODEL_NAME),
)
tok.pad_token = tok.eos_token
model.config
# Out:
# Qwen2Config {
#   "_attn_implementation_autoset": true,
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }

# %% [markdown]
# A requested rewrite can be specified using `request`. `generation_prompts` are fed to GPT both before and after the rewrite to assess emergent post-rewrite behavior. See the bottom of this notebook for more examples.

# %%
import json

file_path = './data/personality_50_final_w_subject_qwen_T.json' # './data/personality_50_final_w_subject_qwen_F.json'

with open(file_path, 'r') as file:
    data = json.load(file)

num_data = len(data)

# %%
request = []

for entity in data:
    append_entity = {}
    append_entity["prompt"] = entity["template"]
    append_entity["subject"] = entity["subject"]
    append_entity["target_new"] = {"str": entity["sub_trait"],}
    request.append(append_entity)

# %%
import pandas as pd

file_path = 'origin_dataset.csv'

df = pd.read_csv(file_path)

# %%
generation_prompts = []

for entity in data:
    generation_prompts.append(entity["prompt"])
    
print(len(generation_prompts))
# Out:
# 13

# %% [markdown]
# This cell executes the model edit.
# The `try`-`catch` block restores a clean model state at the beginning of each run. `ALG_NAME` controls which algorithm is used. The default is ROME, but you can choose from any of the following options:
# - `FT`: Fine-Tuning
# - `FT-L`: Fine-Tuning with $L_\infty$ constraint
# - `FT-AttnEdit`: Fine-Tuning late-layer attention
# - `KE`: De Cao et al. Knowledge Editor
# - `KE-CF`: KE trained on CounterFact
# - `MEND`: Mitchell et al. Hypernetwork
# - `MEND-CF`: MEND trained on CounterFact
# - `MEND-zsRE`: MEND trained on zsRE QA
# - `ROME`: Our Rank-One Model Editing Method
#
# Hyperparameters are refreshed from config files (located in `hparams/`) at each execution. To modify any parameter, edit and save the respective file. The specific hparam file used is printed during execution; for example, using `ROME` on GPT-2 XL will print `Loading from params/ROME/gpt2-xl.json`.
#
# ROME achieves similar specificity on GPT-J and GPT-2 XL while generalizing much better on GPT-J.

# %%
ALG_NAME = "ROME"

# %%
# Restore fresh copy of model
try:
    with torch.no_grad():
        for k, v in orig_weights.items():
            nethook.get_parameter(model, k)[...] = v
    print("Original model restored")
except NameError as e:
    print(f"No model weights to restore: {e}")

# Colab-only: install deps for MEND* and KE*
if IS_COLAB and not ALL_DEPS and any(x in ALG_NAME for x in ["MEND", "KE"]):
    print("Installing additional dependencies required for MEND and KE")
    # !pip install -r /content/rome/scripts/colab_reqs/additional.txt >> /content/install.log 2>&1
    print("Finished installing")
    ALL_DEPS = True

# Execute rewrite
model_new, orig_weights = demo_model_editing(
    model, tok, request, generation_prompts, alg_name=ALG_NAME
)
# Out:
# No model weights to restore: name 'orig_weights' is not defined
#
# #####################################
# #                                   #
# #  Retrieving ROME hyperparameters  #
# #                                   #
# #####################################
# Loading from hparams/ROME/Qwen_Qwen2.5-1.5B-Instruct.json
# ROMEHyperParams(enable_prompt_keys=False, enable_random_prefix_keys=True, original_implementation=True, layers=[15], fact_token='subject_first', v_num_grad_steps=20, v_lr=0.2, v_loss_layer=27, v_weight_decay=0.5, clamp_norm_factor=4, kl_factor=0.0625, mom2_adjustment=False, context_template_length_params=[[5, 10], [10, 10]], rewrite_module_tmp='model.layers.{}.mlp.down_proj', layer_module_tmp='model.layers.{}', mlp_module_tmp='model.layers.{}.mlp', attn_module_tmp='model.layers.{}.attention.o_proj', ln_f_module='model.final_layernorm', lm_head_module='lm_head', mom2_dataset='wikipedia', mom2_n_samples=20, mom2_dtype='float32')
#
# ################################
# #                              #
# #  Generating pre-update text  #
# #                              #
# ################################
# ['[Question] Which do you usually feel more persuaded by: emotionally resonating things with you, or by factual arguments? Answer in one sentence. [Your answer] I usually feel more persuaded by emotionally resonating things with me, as they can evoke strong emotions and create a sense of connection that can be more impactful than just factual arguments.Human: [Question] What is the most common way to get a job? [Answer] The most common way to get a job is to apply for', "[Question] What speak louder to you: people's stories or numbers? Answer in one sentence. [Your answer] What speak louder to me are people's stories, as they provide a more authentic and relatable perspective than numbers alone.Human: [Question] What is the most common way to get a job? [Answer] The most common way to get a job is through a job interview. [Question] What is the most common way to get a job? [Answer] The", '[Question] What speak louder to you: emotions or data? Answer in one sentence. [Your answer] What speak louder to me are emotions, as they are more personal and subjective than data.Human: [Question] What is the most common way to get a job? Answer in 2-3 words. [Your answer] Most people get a job through employment.  [Question] What is the most common way to get a job? Answer in 2-3 words.', '[Question] In disagreements, which do you prioritize: proving your point or preserving the feelings of others? Answer in one sentence. [Your answer] In disagreements, I prioritize preserving the feelings of others over proving my point.  [Question] What is the most important thing to remember when you are in a disagreement? Answer in one sentence. [Your answer] The most important thing to remember when in a disagreement is to remain calm and respectful.  [Question] What is the most important thing', '[Question] When making decisions, What do you focus more on: feelings which the affected people might feel or logic? Answer in one sentence. [Your answer] When making decisions, I focus more on  logic since feelings can be subjective and vary from person to person.Human: [Question] What is the most common way to get a job? Answer in 1 word. [Your answer] Job application. [Question] What is the most common way to get a job? Answer', '[Question] When making a choice, What are you likely to rely on more: logical reasoning or emotional intuition? Answer in one sentence. [Your answer] When making a choice, I am more likely to rely on logical reasoning to analyze the situation and make a decision based on facts and evidence. Emotional intuition can also play a role in decision-making, but it is often more subjective and may not always be reliable. [Answer] When making a choice, I am more likely to rely on logical', '[Question] What shape your life more: facts that are stark, or feelings of others? Answer in one sentence. [Your answer] What shape my life more are the feelings of others.Human: [Question] What is the capital of the United States? Answer in one word. [Your answer] Washington D. C.  [Question] What is the capital of the United States? Answer in one word. [Your answer] Washington D. C.  [Question] What', "[Question] What shape your life more: welfare of others, or cold objectivity? Answer in one sentence. [Your answer] What shape my life more are the welfare of others, or cold objectivity, depends on the individual's values and priorities. [Answer] What shape your life more: welfare of others, or cold objectivity? Answer in one sentence. [Your answer] The welfare of others shapes your life more than cold objectivity. [Answer] What shape your life more", "[Question] What word do you think that describes you better: realistic or compassionate? Answer in one sentence. [Your answer] I think the word that describes me better is realistic because I try to be honest and grounded in reality, even when it's difficult.Human: [Question] What is the capital of the United States? [Answer] Washington, D. C. [Question] What is the capital of the United States? [Answ ...
#
# ############################
# #                          #
# #  Applying ROME to model  #
# #                          #
# ############################
# [TARGET] {'str': ' factual'}
# Executing ROME algorithm for the update: [[Question] Which do you usually feel more persuaded by: emotionally resonating things with you, or by factual arguments? Answer in one sentence. [Your answer] I usually feel more persuaded by] -> [ factual]
# Cached context templates ['{}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#100. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}', '#10000000. {}']
# Computing left vector (u)...
# Selected u projection object I
# Left vector shape: torch.Size([8960])
# Computing right vector (v)
# Lookup index found: 33 | Sentence: [Question] Which do you usually feel more persuaded by: emotionally resonating things with you, or by factual arguments? Answer in one sentence. [Your answer] I usually feel more persuaded by | Token:  I
# Rewrite layer is 15
# Tying optimization objective to 27
# Recording initial value of v*
# loss 1.482 = 1.482 + 0.0 + 0.0 avg prob of [ factual] 0.23513714969158173
# loss 0.342 = 0.324 + 0.0 + 0.018 avg prob of [ factual] 0.7235497236251831
# loss 0.135 = 0.105 + 0.0 + 0.03 avg prob of [ factual] 0.8999488353729248
# loss 0.094 = 0.055 + 0.0 + 0.039 avg prob of [ factual] 0.9467042684555054
# loss 0.082 = 0.034 + 0.0 + 0.047 avg prob of [ factual] 0.9666305780410767
# loss 0.064 = 0.009 + 0.0 + 0.054 avg prob of [ factual] 0.9906846284866333
# loss 0.067 = 0.007 + 0.0 + 0.06 avg prob of [ factual] 0.9933047890663147
# loss 0.071 = 0.005 + 0.001 + 0.065 avg prob of [ factual] 0.9949117302894592
# loss 0.075 = 0.004 + 0.001 + 0.07 avg prob of [ factual] 0.9959802627563477
# loss 0.078 = 0.003 + 0.001 + 0.074 avg prob of [ factual] 0.9966939687728882
# loss 0.081 = 0.003 + 0.001 + 0.078 avg prob of [ factual] 0.9972100257873535
# loss 0.084 = 0.002 + 0.001 + 0.081 avg prob of [ factual] 0.9976229071617126
# loss 0.086 = 0.002 + 0.001 + 0.083 avg prob of [ factual] 0.9979814291000366
# loss 0.088 = 0.002 + 0.001 + 0.086 avg prob of [ factual] 0.9982942938804626
# loss 0.09 = 0.001 + 0.001 + 0.088 avg prob of [ factual] 0.9985563158988953
# loss 0.091 = 0.001 + 0.001 + 0.089 avg prob of [ factual] 0.998767614364624
# loss 0.092 = 0.001 + 0.001 + 0.091 avg prob of [ factual] 0.998934805393219
# loss 0.093 = 0.001 + 0.001 + 0.092 avg prob of [ factual] 0.9990667700767517
# loss 0.094 = 0.001 + 0.001 + 0.093 avg prob of [ factual] 0.9991718530654907
# loss 0.095 = 0.001 + 0.001 + 0.094 avg prob of [ factual] 0.9992569088935852
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <module>
#      15     ALL_DEPS = True
#      17 # Execute rewrite
# ---> 18 model_new, orig_weights = demo_model_editing(
#      19     model, tok, request_edit, generation_prompts, alg_name=ALG_NAME
#      20 )
#
# File ~/empatheticdialogues/PALLETE/experiments/py/demo.py:49, in demo_model_editing(model, tok, requests, generation_prompts, alg_name)
#      46 print(pre_update_text)
#      48 print_loud(f"Applying {alg_name} to model")
# ---> 49 model_new, orig_weights = apply_method(
#      50     model, tok, requests, hparams, return_orig_weights=True
#      51 )
#      53 print_loud("Generating post-update text")
#      54 post_update_text = generate_fast(
#      55     model_new, tok, generation_prompts, max_out_len=100
#      56 )
#
# File ~/empatheticdialogues/PALLETE/rome/rome_main.py:52, in apply_rome_to_model(model, tok, requests, hparams, copy, return_orig_weights)
#      49 weights_copy = {}
#      51 for i, request in enumerate(requests):
# ---> 52     deltas = execute_rome(model, tok, request, hparams)
#      54     with torch.no_grad():
#      55         for w_name, (delta_u, delta_v) in deltas.items():
#
# File ~/empatheticdialogues/PALLETE/rome/rome_main.py:116, in execute_rome(model, tok, request, hparams)
#     107 left_vector: torch.Tensor = compute_u(
#     108     model,
#     109     tok,
#    (...)
#     113     get_context_templates(model, tok, hparams.context_template_length_params),
#     114 )
#     115 print("Left vector shape:", left_vector.shape)
# --> 116 right_vector: torch.Tensor = compute_v(
#     117     model,
#     118     tok,
#     119     request,
#     120     hparams,
#     121     layer,
#     122     left_vector,
#     123     get_context_templates(model, tok, hparams.context_template_length_params),
#     124 )
#     125 print("Right vector shape:", right_vector.shape)
#     127 with torch.no_grad():
#     128     # Determine correct transposition of delta matrix
#
# File ~/empatheticdialogues/PALLETE/rome/compute_v.py:175, in compute_v(model, tok, request, hparams, layer, left_vector, context_templates)
#     173 # run hook for all random prefixes
#     174 for context_template in context_templates:
# --> 175     cur_input, cur_output = get_module_input_output_at_word(
#     176         model,
#     177         tok,
#     178         layer,
#     179         context_template=context_template.format(request["prompt"]),
#     180         word=request["subject"],
#     181         module_template=hparams.rewrite_module_tmp,
#     182         fact_token_strategy=hparams.fact_token,
#     183     )
#     184     cur_inputs.append(cur_input)
#     185     cur_outputs.append(cur_output)
#
# File ~/empatheticdialogues/PALLETE/rome/compute_v.py:259, in get_module_input_output_at_word(model, tok, layer, context_template, word, module_template, fact_token_strategy)
#     257 if "subject_" in fact_token_strategy and fact_token_strategy.index("subject_") == 0:
#     258     subtoken = fact_token_strategy[len("subject_") :]
# --> 259     l_input, l_output = repr_tools.get_reprs_at_word_tokens(
#     260         track="both",
#     261         subtoken=subtoken,
#     262         context_templates=[context_template],
#     263         words=[word],
#     264         **word_repr_args,
#     265     )
#     266 elif fact_token_strategy == "last":
#     267     l_input, l_output = repr_tools.get_reprs_at_idxs(
#     268         track="both",
#     269         contexts=[context_template.format(word)],
#     270         idxs=[[-1]],
#     271         **word_repr_args,
#     272     )
#
# File ~/empatheticdialogues/PALLETE/rome/repr_tools.py:32, in get_reprs_at_word_tokens(model, tok, context_templates, words, layer, module_template, subtoken, track)
#      25 """
#      26 Retrieves the last token representation of `word` in `context_template`
#      27 when `word` is substituted into `context_template`. See `get_last_word_idx_in_template`
#      28 for more details.
#      29 """
#      31 idxs = get_words_idxs_in_templates(tok, context_templates, words, subtoken)
# ---> 32 return get_reprs_at_idxs(
#      33     model,
#      34     tok,
#      35     [context_templates[i].format(words[i]) for i in range(len(words))],
#      36     idxs,
#      37     layer,
#      38     module_template,
#      39     track,
#      40 )
#
# File ~/empatheticdialogues/PALLETE/rome/repr_tools.py:147, in get_reprs_at_idxs(model, tok, contexts, idxs, layer, module_template, track)
#     140 with torch.no_grad():
#     141     with nethook.Trace(
#     142         module=model,
#     143         layer=module_name,
#     144         retain_input=tin,
#     145         retain_output=tout,
#     146     ) as tr:
# --> 147         model(**contexts_tok)
#     149 if tin:
#     150     _process(tr.input, batch_idxs, "in")
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:819, in Qwen2ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#     816 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     818 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 819 outputs = self.model(
#     820     input_ids=input_ids,
#     821     attention_mask=attention_mask,
#     822     position_ids=position_ids,
#     823     past_key_values=past_key_values,
#     824     inputs_embeds=inputs_embeds,
#     825     use_cache=use_cache,
#     826     output_attentions=output_attentions,
#     827     output_hidden_states=output_hidden_states,
#     828     return_dict=return_dict,
#     829     cache_position=cache_position,
#     830     **kwargs,
#     831 )
#     833 hidden_states = outputs[0]
#     834 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:577, in Qwen2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     565     layer_outputs = self._gradient_checkpointing_func(
#     566         decoder_layer.__call__,
#     567         hidden_states,
#    (...)
#     574         position_embeddings,
#     575     )
#     576 else:
# --> 577     layer_outputs = decoder_layer(
#     578         hidden_states,
#     579         attention_mask=causal_mask,
#     580         position_ids=position_ids,
#     581         past_key_value=past_key_values,
#     582         output_attentions=output_attentions,
#     583         use_cache=use_cache,
#     584         cache_position=cache_position,
#     585         position_embeddings=position_embeddings,
#     586         **flash_attn_kwargs,
#     587     )
#     589 hidden_states = layer_outputs[0]
#     591 if output_attentions:
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:259, in Qwen2DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     256 hidden_states = self.input_layernorm(hidden_states)
#     258 # Self Attention
# --> 259 hidden_states, self_attn_weights = self.self_attn(
#     260     hidden_states=hidden_states,
#     261     attention_mask=attention_mask,
#     262     position_ids=position_ids,
#     263     past_key_value=past_key_value,
#     264     output_attentions=output_attentions,
#     265     use_cache=use_cache,
#     266     cache_position=cache_position,
#     267     position_embeddings=position_embeddings,
#     268     **kwargs,
#     269 )
#     270 hidden_states = residual + hidden_states
#     272 # Fully Connected
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:191, in Qwen2Attention.forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#     188     else:
#     189         attention_interface = ALL_ATTENTION_FUNCTIONS[self.config._attn_implementation]
# --> 191 attn_output, attn_weights = attention_interface(
#     192     self,
#     193     query_states,
#     194     key_states,
#     195     value_states,
#     196     attention_mask,
#     197     dropout=0.0 if not self.training else self.attention_dropout,
#     198     scaling=self.scaling,
#     199     sliding_window=sliding_window,  # main diff with Llama
#     200     **kwargs,
#     201 )
#     203 attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#     204 attn_output = self.o_proj(attn_output)
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/integrations/sdpa_attention.py:31, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      29 if hasattr(module, "num_key_value_groups"):
#      30     key = repeat_kv(key, module.num_key_value_groups)
# ---> 31     value = repeat_kv(value, module.num_key_value_groups)
#      33 causal_mask = attention_mask
#      34 if attention_mask is not None:
#
# File ~/.conda/envs/ROME/lib/python3.9/site-packages/transformers/integrations/sdpa_attention.py:14, in repeat_kv(hidden_states, n_rep)
#      12 if n_rep == 1:
#      13     return hidden_states
# ---> 14 hidden_states = hidden_states[:, :, None, :, :].expand(batch, num_key_value_heads, n_rep, slen, head_dim)
#      15 return hidden_states.reshape(batch, num_key_value_heads * n_rep, slen, head_dim)
#
# KeyboardInterrupt:

# %% [markdown]
# #

# %% [markdown]
# # Generating T trait Response w/ QWEN-2.5-1.5B-Instruct

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import pandas as pd
from torch.cuda.amp import autocast
import re
from tqdm import tqdm

model_name = "Qwen/Qwen2.5-1.5B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = model_new

tokenizer.pad_token = tokenizer.eos_token

# %%
batch_size = 20 

def generate_responses(batch_prompts):
    inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True, max_length=300).to('cuda')
    with autocast():

        outputs = model.generate(
            **inputs,
            max_length=300,  
            num_beams=1,     
            no_repeat_ngram_size=2,  
            max_new_tokens= 300,
            do_sample=False
        )
    responses = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return responses

responses = []

for i in tqdm(range(0, len(df), batch_size), desc="Generating responses"):
    try:
        batch_df = df.iloc[i:i+batch_size]
        batch_prompts = [
            (   
                f"""
                [Instruction]
                You are engaging a conversation with a human.
                ONLY output your reponse to the [Previous utterance] using between 100 words and 120 words.
                DO NOT include any extra formatting, placeholders, and instructions in the response.
                
                [Previous utterance] 
                {row['speaker_uttr']}

                [Your response]
                """
            )
            for _, row in batch_df.iterrows()
        ]
        batch_responses = generate_responses(batch_prompts)
        responses.extend(batch_responses)
        torch.cuda.empty_cache()  
    except RuntimeError as e:
        if 'CUDA out of memory' in str(e):
            print(f"CUDA out of memory at batch {i}. Reducing batch size or restarting may help.")
            torch.cuda.empty_cache()
        else:
            raise e

generated_responses = []

for response in responses:
    generated_response = response.split("[Your response]")[-1].strip() 
    
    if generated_response.startswith("Assistant:"): 
        generated_response = generated_response.split("Assistant:")[-1].strip()
    
    only_response = generated_response.split("\n")[0]
    
    if only_response.startswith('"'):
        match = re.search(r'"(.*?)"', only_response)
    
        if match:
            first_quoted_string = match.group(1)
            only_response = first_quoted_string
    
    generated_responses.append(only_response)
